# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model='phi3')

# %%
messages = ['my name is Amit']

# %%
output = llm.invoke(messages).content
output
# Out:
# "Hello! It's a pleasure to meet you, Amit. How can I assist you today? Whether it’s information, guidance or just some friendly conversation – feel free to share what’s on your mind."

# %%
messages.append('What is my name ? ')
messages
# Out:
# ['my name is Amit', 'What is my name ? ']

# %%
output = llm.invoke(messages).content
output
# Out:
# 'Your name is Amit. The instruction asks a question that provides the answer within it, and following its format exactly without altering any details would yield "Amit." So, your response to this question should simply be: Your name is Amit. However, since you\'re asking for an exact one-line reply as if answering the original prompt directly, here it is succinctly worded:\n\nYour name is Amit. '
